# %%
import pandas as pd
import numpy as np
import codecs
import csv
import os
import urllib.request
from pathlib import Path

# %%
# Set path to local Visual Crossing API key file
path = Path()
vc_key_file = 'visualcrossing_apikey.txt'
vc_key_filepath = path/'..'/vc_key_file

# Raise exception if key file not found
if not os.path.exists(vc_key_filepath):
    raise FileNotFoundError('Visual Crossing API key file not found! Please check directory.')

# Read in Visual Crossing API key as environment variable
with open(vc_key_filepath, 'r') as f:
    os.environ['vc_api_key'] = f.readline().strip()

# %%
# Make directory for storing downloaded weather data files
weather_dir = 'weather_data'
weather_dir_path = path/'..'/weather_dir

if not os.path.exists(weather_dir_path):
    os.mkdir(weather_dir_path)

# %%
# Read in the longitude and latitude of the centroid of all the counties in New York state
mapping_file = 'mapping.csv'
mapping_file_path = path/'..'/mapping_file
counties = []
with open(mapping_file_path, 'r') as csv_file:
    mapping_reader = csv.DictReader(csv_file)
    for row in mapping_reader:
        long, lat = row['County Centroid'].replace('(', '').replace(')', '').split(', ')
        counties.append((row['County'], long, lat))

# %%
# Check county list
print(f"County list length = {len(counties)}")
for county in counties[:5]:
    print(county)
# Out:
# County list length = 62
# ('BRONX', '40.8448', '-73.8648')
# ('KINGS', '40.6782', '-73.9442')
# ('RICHMOND', '40.5795', '-74.1502')
# ('ALBANY', '42.5882713', '-73.9740136')
# ('SCHENECTADY', '42.8175421', '-74.0435834')

# %%
def get_daily_weather_data(county, start_date, end_date, long, lat, content_type='csv'):
    try:
        print(f"Downloading weather data for {county} county...")
        url = f'https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/{long},{lat}/{start_date}/{end_date}?unitGroup=us&include=days&key={os.environ.get("vc_api_key")}&contentType={content_type}'
        result_bytes = urllib.request.urlopen(url)
        # Parse the results as CSV
        csv_text = csv.reader(codecs.iterdecode(result_bytes, 'utf-8'))
        county_filename = county.replace(' ', '_') + '.csv'
        csv_filepath = weather_dir_path/county_filename
        # Create new CSV file and write to it
        with open(csv_filepath, 'x', newline='') as csv_file:
            csv_writer = csv.writer(csv_file)
            csv_writer.writerows(csv_text)
        print(f"Weather data for {county} county successfully downloaded!")
    except urllib.error.HTTPError as e: # Handle HTTP exceptions
        error_info = e.read().decode()
        print('Error code: ', e.code, error_info)
        return
    except urllib.error.URLError as e: # Handle URL exceptions
        error_info = e.read().decode()
        print('Error code: ', e.code, error_info)
        return

# %%
# Test for BRONX county in past 7 days
start_date = '2022-11-01' # Dates are in YYYY-MM-DD format
end_date = '2022-11-07' # End date is inclusive
get_daily_weather_data('BRONX', start_date, end_date, '40.8448', '-73.8648')
# Out:
# Weather data for BRONX county successfully downloaded!

# %%
# Download weather data for all NY counties
start_date = '2020-01-01' # Dates are in YYYY-MM-DD format
end_date = '2022-09-30' # End date is inclusive
for county in counties:
    county_name, long, lat = county
    get_daily_weather_data(county_name, start_date, end_date, long, lat)
# Out:
# Downloading weather data for BRONX county...
# Weather data for BRONX county successfully downloaded!
# Downloading weather data for KINGS county...
# Weather data for KINGS county successfully downloaded!
# Downloading weather data for RICHMOND county...
# Weather data for RICHMOND county successfully downloaded!
# Downloading weather data for ALBANY county...
# Weather data for ALBANY county successfully downloaded!
# Downloading weather data for SCHENECTADY county...
# Weather data for SCHENECTADY county successfully downloaded!
# Downloading weather data for CHAUTAUQUA county...
# Weather data for CHAUTAUQUA county successfully downloaded!
# Downloading weather data for DUTCHESS county...
# Weather data for DUTCHESS county successfully downloaded!
# Downloading weather data for CORTLAND county...
# Weather data for CORTLAND county successfully downloaded!
# Downloading weather data for RENSSELAER county...
# Weather data for RENSSELAER county successfully downloaded!
# Downloading weather data for CAYUGA county...
# Weather data for CAYUGA county successfully downloaded!
# Downloading weather data for ONONDAGA county...
# Weather data for ONONDAGA county successfully downloaded!
# Downloading weather data for GENESEE county...
# Weather data for GENESEE county successfully downloaded!
# Downloading weather data for COLUMBIA county...
# Weather data for COLUMBIA county successfully downloaded!
# Downloading weather data for NASSAU county...
# Weather data for NASSAU county successfully downloaded!
# Downloading weather data for ONEIDA county...
# Weather data for ONEIDA county successfully downloaded!
# Downloading weather data for CHENANGO county...
# Weather data for CHENANGO county successfully downloaded!
# Downloading weather data for LIVINGSTON county...
# Weather data for LIVINGSTON county successfully downloaded!
# Downloading weather data for ERIE county...
# Weather data for ERIE county successfully downloaded!
# Downloading weather data for ALLEGANY county...
# Weather data for ALLEGANY county successfully downloaded!
# Downloading weather data for ORLEANS county...
# Weather data for ORLEANS county successfully downloaded!
# Downloading weather data for CATTARAUGUS county...
# Weather data for CATTARAUGUS county successfully downloaded!
# Downloading weather data for CLINTON county...
# Weather data for CLINTON county successfully downloaded!
# Downloading weather data for WAYNE county...
# Weather data for WAYNE county successfully downloaded!
# Downloading weather data for GREENE county...
# Weather data for GREENE county successfully downloaded!
# Downloading weather data for ROCKLAND county...
# Weather data for ROCKLAND county successfully downloaded!
# Downloading weather data for JEFFERSON county...
# Weather data for JEFFERSON county successfully downloaded!
# Downloading weather data for PUTNAM county...
# Weather data for PUTNAM county successfully downloaded!
# Downloading weather data for FRANKLIN county...
# Weather data for FRANKLIN county successfully downloaded!
# Downloading weather data for ESSEX county...
# Weather data for ESSEX county successfully downloaded!
# Downloading weather data for WYOMING county...
# Weather data for WYOMING county successfully downloaded!
# Downloading weather data for LEWIS county...
# Weather data for LEWIS county successfully downloaded!
# Downloading weather data for YATES county...
# Weather data for YATES county successfully downloaded!
# Downloading weather data for SUFFOLK county...
# Weather data for SUFFOLK county successfully downloaded!
# Downloading weather data for WARREN county...
# Weather data for WARREN county successfully downloaded!
# Downloading weather data for OTSEGO county...
# Weather data for OTSEGO county successfully downloaded!
# Downloading weather data for HERKIMER county...
# Weather data for HERKIMER county successfully downloaded!
# Downloading weather data for MONTGOMERY county...
# Weather data for MONTGOMERY county successfully downloaded!
# Downloading weather data for STEUBEN county...
# Weather data for STEUBEN county successfully downloaded!
# Downloading weather data for SCHOHARIE county...
# Weather data for SCHOHARIE county successfully downloaded!
# Downloading weather data for FULTON county...
# Weather data for FULTON county successfully downloaded!
# Downloading weather data for NEW YORK county...
# Weather data for NEW YORK county successfully downloaded!
# Downloading weather data for SENECA county...
# Weather data for SENECA county successfully downloaded!
# Downloading weather data for CHEMUNG county...
# Weather data for CHEMUNG county successfully downloaded!
# Downloading weather data for SARATOGA county...
# Weather data for SARATOGA county successfully downloaded!
# Downloading weather data for NIAGARA county...
# Weather data for NIAGARA county successfully downloaded!
# Downloading weather data for BROOME county...
# Weather data for BROOME county successfully downloaded!
# Downloading weather data for MADISON county...
# Weather data for MADISON county successfully downloaded!
# Downloading weather data for ONTARIO county...
# Weather data for ONTARIO county successfully downloaded!
# Downloading weather data for ULSTER county...
# Weather data for ULSTER county successfully downloaded!
# Downloading weather data for WESTCHESTER county...
# Weather data for WESTCHESTER county successfully downloaded!
# Downloading weather data for DELAWARE county...
# Weather data for DELAWARE county successfully downloaded!
# Downloading weather data for ORANGE county...
# Weather data for ORANGE county successfully downloaded!
# Downloading weather data for TOMPKINS county...
# Weather data for TOMPKINS county successfully downloaded!
# Downloading weather data for SCHUYLER county...
# Weather data for SCHUYLER county successfully downloaded!
# Downloading weather data for QUEENS county...
# Weather data for QUEENS county successfully downloaded!
# Downloading weather data for SULLIVAN county...
# Weather data for SULLIVAN county successfully downloaded!
# Downloading weather data for MONROE county...
# Weather data for MONROE county successfully downloaded!
# Downloading weather data for WASHINGTON county...
# Weather data for WASHINGTON county successfully downloaded!
# Downloading weather data for ST LAWRENCE county...
# Weather data for ST LAWRENCE county successfully downloaded!
# Downloading weather data for HAMILTON county...
# Weather data for HAMILTON county successfully downloaded!
# Downloading weather data for OSWEGO county...
# Weather data for OSWEGO county successfully downloaded!
# Downloading weather data for TIOGA county...
# Weather data for TIOGA county successfully downloaded!

# %%
# Make directory for storing processed/cleaned weather data file
cleaned_weather_dir_path = path/'..'/'data'/'processed'/'weather_data'
cleaned_weather_csv = 'weather_data.csv'
cleaned_weather_csv_path = cleaned_weather_dir_path/cleaned_weather_csv

if not os.path.exists(cleaned_weather_dir_path):
    os.mkdir(cleaned_weather_dir_path)

# Create new csv file for storing cleaned and aggregated weather data
with open(cleaned_weather_csv_path, 'x', newline='') as f:
    print(f"Created new CSV file at: {cleaned_weather_csv_path}")
# Out:
# Created new CSV file at: ../data/processed/weather_data/weather_data.csv

# %%
def process_weather_data(county, dest_csv_file_path, first=False):
    print(f"Processing weather data for {county} county...")
    county_filename = county.replace(' ', '_')
    csv_filename = county_filename + '.csv'
    # Read data from raw CSV file
    df_county = pd.read_csv(weather_dir_path/csv_filename)
    # Remove redundant columns
    df_county = df_county.drop(labels=['description', 'icon', 'stations'], axis=1)
    df_county['name'] = county
    df_county = df_county.rename(columns={'name': 'county'})
    # Drop first few and last few rows to ensure conformity with weekly-basis
    df_county = df_county.drop(labels=[0, 1, 2, 3, 998, 999, 1000, 1001, 1002, 1003], axis=0).reset_index(drop=True)
    agg_col_map = {col: 'mean' for col in df_county.columns}
    # Delete unnecessary columns
    del agg_col_map['sunrise']
    del agg_col_map['sunset']
    # Choose last appeared value for these columns
    agg_col_map['county'] = 'last'
    agg_col_map['datetime'] = 'last'
    # Choose the most frequent value for these columns
    agg_col_map['preciptype'] = lambda x: '' if len(pd.Series.mode(x)) == 0 else pd.Series.mode(x)[0]
    agg_col_map['conditions'] = lambda x: '' if len(pd.Series.mode(x)) == 0 else pd.Series.mode(x)[0]
    # Group data by every 7 days
    df_county_agg = df_county.groupby(df_county.index//7).agg(agg_col_map)
    # Append dataframe to CSV file
    if first:
        df_county_agg.to_csv(dest_csv_file_path, mode='a', index=False, header=True)
    else:
        df_county_agg.to_csv(dest_csv_file_path, mode='a', index=False, header=False)
    print(f"Appended cleaned weather data for {county} county to CSV!")

# %%
# Process weather data for all counties
for i in range(len(counties)):
    county_name = counties[i][0]
    if i == 0:
        process_weather_data(county_name, cleaned_weather_csv_path, True)
    else:
        process_weather_data(county_name, cleaned_weather_csv_path)
# Out:
# Processing weather data for BRONX county...
# Appended cleaned weather data for BRONX county to CSV!
# Processing weather data for KINGS county...
# Appended cleaned weather data for KINGS county to CSV!
# Processing weather data for RICHMOND county...
# Appended cleaned weather data for RICHMOND county to CSV!
# Processing weather data for ALBANY county...
# Appended cleaned weather data for ALBANY county to CSV!
# Processing weather data for SCHENECTADY county...
# Appended cleaned weather data for SCHENECTADY county to CSV!
# Processing weather data for CHAUTAUQUA county...
# Appended cleaned weather data for CHAUTAUQUA county to CSV!
# Processing weather data for DUTCHESS county...
# Appended cleaned weather data for DUTCHESS county to CSV!
# Processing weather data for CORTLAND county...
# Appended cleaned weather data for CORTLAND county to CSV!
# Processing weather data for RENSSELAER county...
# Appended cleaned weather data for RENSSELAER county to CSV!
# Processing weather data for CAYUGA county...
# Appended cleaned weather data for CAYUGA county to CSV!
# Processing weather data for ONONDAGA county...
# Appended cleaned weather data for ONONDAGA county to CSV!
# Processing weather data for GENESEE county...
# Appended cleaned weather data for GENESEE county to CSV!
# Processing weather data for COLUMBIA county...
# Appended cleaned weather data for COLUMBIA county to CSV!
# Processing weather data for NASSAU county...
# Appended cleaned weather data for NASSAU county to CSV!
# Processing weather data for ONEIDA county...
# Appended cleaned weather data for ONEIDA county to CSV!
# Processing weather data for CHENANGO county...
# Appended cleaned weather data for CHENANGO county to CSV!
# Processing weather data for LIVINGSTON county...
# Appended cleaned weather data for LIVINGSTON county to CSV!
# Processing weather data for ERIE county...
# Appended cleaned weather data for ERIE county to CSV!
# Processing weather data for ALLEGANY county...
# Appended cleaned weather data for ALLEGANY county to CSV!
# Processing weather data for ORLEANS county...
# Appended cleaned weather data for ORLEANS county to CSV!
# Processing weather data for CATTARAUGUS county...
# Appended cleaned weather data for CATTARAUGUS county to CSV!
# Processing weather data for CLINTON county...
# Appended cleaned weather data for CLINTON county to CSV!
# Processing weather data for WAYNE county...
# Appended cleaned weather data for WAYNE county to CSV!
# Processing weather data for GREENE county...
# Appended cleaned weather data for GREENE county to CSV!
# Processing weather data for ROCKLAND county...
# Appended cleaned weather data for ROCKLAND county to CSV!
# Processing weather data for JEFFERSON county...
# Appended cleaned weather data for JEFFERSON county to CSV!
# Processing weather data for PUTNAM county...
# Appended cleaned weather data for PUTNAM county to CSV!
# Processing weather data for FRANKLIN county...
# Appended cleaned weather data for FRANKLIN county to CSV!
# Processing weather data for ESSEX county...
# Appended cleaned weather data for ESSEX county to CSV!
# Processing weather data for WYOMING county...
# Appended cleaned weather data for WYOMING county to CSV!
# Processing weather data for LEWIS county...
# Appended cleaned weather data for LEWIS county to CSV!
# Processing weather data for YATES county...
# Appended cleaned weather data for YATES county to CSV!
# Processing weather data for SUFFOLK county...
# Appended cleaned weather data for SUFFOLK county to CSV!
# Processing weather data for WARREN county...
# Appended cleaned weather data for WARREN county to CSV!
# Processing weather data for OTSEGO county...
# Appended cleaned weather data for OTSEGO county to CSV!
# Processing weather data for HERKIMER county...
# Appended cleaned weather data for HERKIMER county to CSV!
# Processing weather data for MONTGOMERY county...
# Appended cleaned weather data for MONTGOMERY county to CSV!
# Processing weather data for STEUBEN county...
# Appended cleaned weather data for STEUBEN county to CSV!
# Processing weather data for SCHOHARIE county...
# Appended cleaned weather data for SCHOHARIE county to CSV!
# Processing weather data for FULTON county...
# Appended cleaned weather data for FULTON county to CSV!
# Processing weather data for NEW YORK county...
# Appended cleaned weather data for NEW YORK county to CSV!
# Processing weather data for SENECA county...
# Appended cleaned weather data for SENECA county to CSV!
# Processing weather data for CHEMUNG county...
# Appended cleaned weather data for CHEMUNG county to CSV!
# Processing weather data for SARATOGA county...
# Appended cleaned weather data for SARATOGA county to CSV!
# Processing weather data for NIAGARA county...
# Appended cleaned weather data for NIAGARA county to CSV!
# Processing weather data for BROOME county...
# Appended cleaned weather data for BROOME county to CSV!
# Processing weather data for MADISON county...
# Appended cleaned weather data for MADISON county to CSV!
# Processing weather data for ONTARIO county...
# Appended cleaned weather data for ONTARIO county to CSV!
# Processing weather data for ULSTER county...
# Appended cleaned weather data for ULSTER county to CSV!
# Processing weather data for WESTCHESTER county...
# Appended cleaned weather data for WESTCHESTER county to CSV!
# Processing weather data for DELAWARE county...
# Appended cleaned weather data for DELAWARE county to CSV!
# Processing weather data for ORANGE county...
# Appended cleaned weather data for ORANGE county to CSV!
# Processing weather data for TOMPKINS county...
# Appended cleaned weather data for TOMPKINS county to CSV!
# Processing weather data for SCHUYLER county...
# Appended cleaned weather data for SCHUYLER county to CSV!
# Processing weather data for QUEENS county...
# Appended cleaned weather data for QUEENS county to CSV!
# Processing weather data for SULLIVAN county...
# Appended cleaned weather data for SULLIVAN county to CSV!
# Processing weather data for MONROE county...
# Appended cleaned weather data for MONROE county to CSV!
# Processing weather data for WASHINGTON county...
# Appended cleaned weather data for WASHINGTON county to CSV!
# Processing weather data for ST LAWRENCE county...
# Appended cleaned weather data for ST LAWRENCE county to CSV!
# Processing weather data for HAMILTON county...
# Appended cleaned weather data for HAMILTON county to CSV!
# Processing weather data for OSWEGO county...
# Appended cleaned weather data for OSWEGO county to CSV!
# Processing weather data for TIOGA county...
# Appended cleaned weather data for TIOGA county to CSV!
